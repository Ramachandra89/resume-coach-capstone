# %%
from resume_parser import ResumeParser
# Test code
parser = ResumeParser()
try:
    # Replace with your file path
    text = parser.parse_resume("/Users/rahultaduri/Downloads/Resume_RRTaduri.pdf")
    print(text)
except Exception as e:
    print(f"Error: {str(e)}")
# Out:
# RAMACHANDRA RAHUL TADURI
# (+1) 614 843 4715 ⋄rahul.taduri@gmail.com ⋄Secaucus, NJ
# EDUCATION
# The Ohio State University, Columbus August 2013 - May 2015
# Master of Science, Department of Mechanical and Aerospace Engineering
# National Institute of Technology, Surathkal August 2006 - May 2010
# Bachelor of Technology in Mechanical Engineering
# WORK EXPERIENCE
# Actasys Inc. October 2021 - March 2024
# Compliance & NVH Lead
# Managerial Experience
# ·Led engineering efforts to conceptualize, design, and develop compliant acoustic and vibration solu-
# tions for an electromechanical actuator used in sensor cleaning and cooling applications.
# ·Supported multi-year technology product roadmap with detailed countermeasure strategies and time-
# lines to ensure the successful execution of projects.
# ·Surveyed literature to formulate test methods, requirements followed by instrumentation, measurement,
# ...

# %%
from resume_parser import ResumeParser

parser = ResumeParser()
try:
    file_path = "/Users/rahultaduri/Downloads/LIST OF RESOURCES FOR ML TRANSITION.docx"
    text = parser.parse_resume(file_path)
    print("Successfully parsed file!")
    print("\nFirst 500 characters of content:")
    print(text[:500])
except Exception as e:
    print(f"Error: {str(e)}")
# Out:
# Error: 'utf-8' codec can't decode byte 0xb2 in position 10: invalid start byte
